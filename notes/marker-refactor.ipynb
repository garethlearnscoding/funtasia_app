# %% [markdown]
# <table border="1" style="border-collapse: collapse; font-family: monospace;">
#     <tr style="background-color: #e8e8e8;">
#         <th colspan="2" style="padding: 8px; text-align: center;">QRMarker</th>
#     </tr>
#     <tr>
#         <td style="padding: 8px; vertical-align: top;">- attributes</td>
#         <td style="padding: 8px;">- scene: THREE.Scene<br>- font: THREE.Font<br>- markerHeight: number = 0.8<br>- group: THREE.Group<br>- activeMaterial: THREE.MeshBasicMaterial<br>- greyMaterial: THREE.MeshBasicMaterial<br>- outlineMaterialActive: THREE.LineBasicMaterial<br>- outlineMaterialGrey: THREE.LineBasicMaterial<br>- ring: THREE.Mesh<br>- ringOutline: THREE.LineSegments<br>- markerModel: THREE.Group<br>- textLabelGroup: THREE.Group<br>- textMaterialActive: THREE.MeshBasicMaterial<br>- textMesh: THREE.Mesh<br>- textBgMaterial: THREE.MeshBasicMaterial<br>- textBgMesh: THREE.Mesh<br>- startTime: number<br>- greyDelay: number<br>- isGrey: boolean<br>+ {static} appState: AppState<br>+ {static} font: THREE.Font</td>
#     </tr>
#     <tr>
#         <td style="padding: 8px; vertical-align: top;">+ methods</td>
#         <td style="padding: 8px;">+ QRMarker(scene, position, font, greyDelay) : Constructor - creates marker with ring, 3D model, and text label<br>+ animate(time, camera) : void - Updates floating effect, billboarding, and checks grey-out timer<br>- greyOut() : void - Changes materials to grey and removes text label after delay expires<br>+ clear() : void - Disposes geometries/materials and removes marker from scene</td>
#     </tr>
# </table>

# %% [markdown]
# <table border="1" style="border-collapse: collapse; font-family: monospace;">
#     <tr style="background-color: #e8e8e8;">
#         <th colspan="2" style="padding: 8px; text-align: center;">Icon</th>
#     </tr>
#     <tr>
#         <td style="padding: 8px; vertical-align: top;">- attributes</td>
#         <td style="padding: 8px;">- icontype: string<br>- iconPath: string<br>- position: THREE.Vector3<br>- level: string<br>- group: THREE.Group<br>- material: THREE.SpriteMaterial<br>- sprite: THREE.Sprite<br>- baseScale: number = 0.8<br>+ {static} appState: any<br>+ {static} iconPaths: object<br>+ {static} iconsVisible: boolean = true<br>+ {static} activeLevel: string = null<br>+ {static} allIcons: array = []<br>+ {static} scene: THREE.Scene = null</td>
#     </tr>
#     <tr>
#         <td style="padding: 8px; vertical-align: top;">+ methods</td>
#         <td style="padding: 8px;">+ Icon(type, position, level) : Constructor - creates sprite icon with billboarding effect<br>+ {static} state(isVisible) : void - Controls visibility state of all icons<br>+ {static} setLevel(levelId) : void - Sets active level to show icons for<br>+ {static} updateVisibility() : void - Syncs visibility across all icon instances<br>+ animate(time, camera) : void - Scales icon based on distance and hides when too small<br>+ clear() : void - Disposes textures/materials and removes icon from scene</td>
#     </tr>
# </table>

# %% [markdown]
# <table border="1" style="border-collapse: collapse; font-family: monospace;">
#     <tr style="background-color: #e8e8e8;">
#         <th colspan="2" style="padding: 8px; text-align: center;">Floor</th>
#     </tr>
#     <tr>
#         <td style="padding: 8px; vertical-align: top;">- attributes</td>
#         <td style="padding: 8px;">- id: string<br>- modelPath: string<br>- infoDataPath: string<br>- sceneModel: THREE.Group<br>- interactiveObjects: array = []<br>- cameraConfig: object<br>+ {static} appState: any<br>+ {static} childModels: object<br>+ {static} floors: object = {}<br>+ {static} currentFloor: Floor = null<br>+ {static} allMarkers: object = {}</td>
#     </tr>
#     <tr>
#         <td style="padding: 8px; vertical-align: top;">+ methods</td>
#         <td style="padding: 8px;">+ Floor(id, modelPath, infoDataPath) : Constructor - Creates floor instance with camera config defaults<br>+ {static} registerFloor(floor) : void - Adds floor object to static floors dictionary<br>+ isLoaded() : boolean - Returns whether floor model has been loaded<br>+ load(appState) : Promise&lt;void&gt; - Lazily loads GLTF model and parses interactive objects<br>+ activate(camera, controls) : void - Shows floor and applies camera constraints<br>+ hide() : void - Hides floor model from view<br>+ attachParsedData(model, interactiveObjects, cameraConfig) : void - Populates internal state after GLTF parsing</td>
#     </tr>
# </table>
